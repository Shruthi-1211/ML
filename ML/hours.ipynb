# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df=pd.read_csv("Hours.csv")
print("Data loaded successfully. Here are the first five rows:")
print(df.head())
# Out:
# Data loaded successfully. Here are the first five rows:
#    Hours  Marks
# 0    2.3     21
# 1    4.4     48
# 2    6.7     60
# 3    8.0     70
# 4    2.2     30

# %%
x= df.iloc[:,:-1].values
y=df.iloc[:,1].values
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)
print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
regressor=LinearRegression()
regressor.fit(x_train , y_train)
print("Training Complete")
# Out:
# Training Complete

# %%
y_pred=regressor.predict(x_test)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f"Mean Absolute Error:{mae:.2f}")
print(f"R-squared Score:{r2:.2f}")
# Out:
# Mean Absolute Error:5.29
# R-squared Score:0.89

# %%
line=regressor.coef_*x+ regressor.intercept_
plt.figure(figsize=(10,6))
plt.scatter(x,y,color="red",edgecolor="black",s=100,label="Data Points")
plt.plot(x,line,color="crimson",linewidth=2,label="Regression Line")
plt.title("Linear Regresssion Hours vs marks",fontsize=15)
plt.xlabel("Hours Studied",fontsize=12)
plt.ylabel("Percentage Score",fontsize=12)
plt.legend()
plt.show()

# %%
hours=float(input("Rnters Hours:"))
prediction=regressor.predict([[hours]])
print(f"Predicted score for {hours} hours of study:{prediction[0]:.2f}")
# Out:
# Predicted score for 7.0 hours of study:74.26
